# %%
import vmodel
import os
import numpy as np
import h5py
import datetime
import scipy.spatial
import math
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import seaborn as sns; sns.set_theme()
import pandas as pd
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import FormatStrFormatter
plt.style.use('default')

# %%
steps = 10
reps = 20
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_dphi_astrIID_astr_dphi.npy")

paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps)

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = 2,cbar_kws={'label': "IID"},
                 cmap="RdPu")

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("angular noise $D_{φ}$", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Occluded, FOV Θ = 330 °")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("HM_IID_occ_dphi.pdf",bbox_inches="tight")

# %%
steps = 10
reps = 20
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_dphi_astr_vorIID_astr_dphi.npy")

paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps)

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = 2,cbar_kws={'label': "IID"},
                 cmap="RdPu")

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("angular noise $D_{φ}$", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Voronoi, FOV Θ = 330 °")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("HM_IID_vor_dphi.pdf",bbox_inches="tight")

# %%
#mill = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis250_dphi_astr_occ_col_mill_astr_dphi.npy")
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis240v2_dphi_astr_occIID_astr_dphi.npy")

steps = 10
reps = 20


paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps)

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = 2,cbar_kws={'label': "IID"},
                 cmap="RdPu")#, norm=LogNorm())

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("angular noise $D_{φ}$", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Occluded, FOV Θ = 240 °")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("HM_IID_occ_dphi_240.pdf",bbox_inches="tight")

# %%
#mill = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis250_dphi_astr_occ_col_mill_astr_dphi.npy")
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis240v2_dphi_astr_occIID_astr_dphi.npy")

steps = 10
reps = 20


paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps)

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = 2,cbar_kws={'label': "IID"},
                 cmap="RdPu", norm=LogNorm())

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("angular noise $D_{φ}$", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Occluded, FOV Θ = 240 °")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("HM_IID_occ_dphi_240_log.pdf",bbox_inches="tight")

# %%
#mill = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis250_dphi_astr_occ_col_mill_astr_dphi.npy")
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis240v2_dphi_astr_vorIID_astr_dphi.npy")

steps = 10
reps = 20


paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps)

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = 2,cbar_kws={'label': "IID"},
                 cmap="RdPu")

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("angular noise $D_{φ}$", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Voronoi, FOV Θ = 240 °")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("HM_IID_vor_dphi_240.pdf",bbox_inches="tight")

# %%
#mill = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis250_dphi_astr_occ_col_mill_astr_dphi.npy")
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis240v2_dphi_astr_vorIID_astr_dphi.npy")

steps = 10
reps = 20


paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps)

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = 2,cbar_kws={'label': "IID"},
                 cmap="RdPu", norm=LogNorm())

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("angular noise $D_{φ}$", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Voronoi, FOV Θ = 240 °")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("HM_IID_vor_dphi_240_log.pdf",bbox_inches="tight")

# %%
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis_astrIID_astr_visPrey.npy")

steps = 10
reps = 20



paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,360,steps)

xticks = []



paraChange2_val = paraChange2_val.astype(int)
for i in range(steps):
    xticks.append(str(paraChange2_val[i])+" °")

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = xticks,cbar_kws={'label': "IID"},
                 cmap="RdPu")

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("FOV Θ", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Occluded, $D_{φ}$ = 0.2")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.savefig("HM_IID_occ_vis.pdf",bbox_inches="tight")

# %%
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis_astrIID_astr_visPrey.npy")

steps = 10
reps = 20



paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,360,steps)

xticks = []



paraChange2_val = paraChange2_val.astype(int)
for i in range(steps):
    xticks.append(str(paraChange2_val[i])+" °")

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = xticks,cbar_kws={'label': "IID"},
                 cmap="RdPu", norm=LogNorm())

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("FOV Θ", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Occluded, $D_{φ}$ = 0.2")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.savefig("HM_IID_occ_vis_log.pdf",bbox_inches="tight")

# %%
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis_astr_vorIID_astr_visPrey.npy")

steps = 10
reps = 20

xticks = []

paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,360,steps)
paraChange2_val = paraChange2_val.astype(int)
for i in range(steps):
    xticks.append(str(paraChange2_val[i])+" °")

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = xticks,cbar_kws={'label': "IID"},
                 cmap="RdPu")

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("FOV Θ", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Voronoi, $D_{φ}$ = 0.2")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.savefig("HM_IID_vor_vis.pdf",bbox_inches="tight")

# %%
pol = np.load("/home/lars/vmodel_output/longsim_data/longsim_preyvis_astr_vorIID_astr_visPrey.npy")

steps = 10
reps = 20

xticks = []

paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,360,steps)
paraChange2_val = paraChange2_val.astype(int)
for i in range(steps):
    xticks.append(str(paraChange2_val[i])+" °")

#pol = np.mean(pol, axis = 3)
pol = np.mean(pol, axis = 2)

df = pd.DataFrame(np.flip(pol, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df,  yticklabels = 2, xticklabels = xticks,cbar_kws={'label': "IID"},
                 cmap="RdPu", norm=LogNorm())

plt.tight_layout()
plt.gcf().set_size_inches(4,3.45)
plt.xlabel("FOV Θ", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("Voronoi, $D_{φ}$ = 0.2")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.savefig("HM_IID_vor_vis_log.pdf",bbox_inches="tight")
