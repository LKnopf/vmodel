# %%
import vmodel
import os
import numpy as np
import h5py
import datetime
import scipy.spatial
import math
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import seaborn as sns; sns.set_theme()
import pandas as pd

# %%
steps = 10
reps = 20
paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0,1,steps) #repradprey

data = np.load("/home/lars/vmodel_output/longsim_dphi_astr_NN_astr_dphi.npy")
data = np.mean(data, axis = 3)
data = np.mean(data, axis = 2)

df = pd.DataFrame(np.flip(data, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df, cbar_kws={'label': "Mean # of Neighbors"},
                 cmap="Reds")

plt.tight_layout()
plt.gcf().set_size_inches(10,7.85)
plt.xlabel("Angular Noise", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("Alignment Strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
name = "HM_NN_str_dphi"
plt.savefig("/home/lars/vmodel_output/"+str(name)+".png",bbox_inches="tight")
plt.savefig("HM_NN_dphi_vis330.png",bbox_inches="tight")

# %%
steps = 10
reps = 20
paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.round(np.linspace(0,1,steps),3)

data = np.load("/home/lars/vmodel_output/longsim_preyvis250_dphi_astr_occ_col_NN_astr_dphi.npy")
data = np.mean(data, axis = 3)
data = np.mean(data, axis = 2)


df = pd.DataFrame(np.flip(data, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df, cbar_kws={'label': "Mean # of Neighbors"},
                 cmap="Reds")

plt.tight_layout()
plt.gcf().set_size_inches(10,7.85)
plt.xlabel("dphi", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("prey vision = 250")
name = "HM_NN_250_str_dphi"
plt.savefig("HM_NN_dphi_vis250.png",bbox_inches="tight")

# %%
steps = 10
reps = 20
paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.round(np.linspace(0,1,steps),3)

data = np.load("/home/lars/vmodel_output/longsim_preyvis240_dphi_astr_occ_col_NN_astr_dphi.npy")
data = np.mean(data, axis = 3)
data = np.mean(data, axis = 2)


df = pd.DataFrame(np.flip(data, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df, cbar_kws={'label': "Mean # of Neighbors"},
                 cmap="Reds")

plt.tight_layout()
plt.gcf().set_size_inches(10,7.85)
plt.xlabel("dphi", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
plt.title("prey vision = 240")
name = "HM_NN_250_str_dphi"
plt.savefig("/home/lars/vmodel_output/"+str(name)+".png",bbox_inches="tight")

# %%
steps = 10
reps = 20
paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.linspace(0.7,1.7,steps) #repradprey

data = np.load("/home/lars/vmodel_output/longsim_reprad_astr_NN_astr_repRadPrey.npy")
data = np.mean(data, axis = 3)
data = np.mean(data, axis = 2)

df = pd.DataFrame(np.flip(data, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df, cbar_kws={'label': "Mean # of Neighbors"},
                 cmap="Reds")

plt.tight_layout()
plt.gcf().set_size_inches(10,7.85)
plt.xlabel("Repulsion Radius of Prey", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("Alignment Strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
name = "HM_NN_str_repradprey"
plt.savefig("HM_NN_reprad_vis330.png",bbox_inches="tight")

# %%
steps = 10
reps = 20
paraChange1_val = np.linspace(0,3,steps)
paraChange2_val = np.round(np.linspace(30,359,steps),3)

data = np.load("/home/lars/vmodel_output/longsim_preyvis_astr_NN_astr_visPrey.npy")
data = np.mean(data, axis = 3)
data = np.mean(data, axis = 2)


df = pd.DataFrame(np.flip(data, axis = 0))

df.columns = np.round(paraChange2_val,2)
df.index = np.round(paraChange1_val,2)[::-1]


#plt.title(figname, fontsize = 12, pad = 20) # title with fontsize 20
ax = sns.heatmap(df, cbar_kws={'label': "Mean # of Neighbors"},
                 cmap="Reds")

plt.tight_layout()
plt.gcf().set_size_inches(10,7.85)
plt.xlabel("vision cone prey", fontsize = 15) # x-axis label with fontsize 15
plt.ylabel("alignment strength " + u'$μ_{alg}$', fontsize = 15) # y-axis label with fontsize 15
name = "HM_NN_str_pvis"
plt.savefig("HM_NN_vis.png",bbox_inches="tight")
